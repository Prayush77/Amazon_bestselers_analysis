# %%
import pandas as pd

# %%
df=pd.read_csv(r"D:\Projects\amazon-bestsellers-analysis\data\books.csv")

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
price_rating =df[['Price','User Rating']]

# %%
price_rating.corr()
# Out:
#                 Price  User Rating
# Price        1.000000    -0.133086
# User Rating -0.133086     1.000000

# %%
# visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='Price',y='User Rating',data=df)
plt.show()

# %%
df.groupby('Genre')['User Rating'].mean()
# Out:
# Genre
# Fiction        4.648333
# Non Fiction    4.595161
# Name: User Rating, dtype: float64

# %%
df.groupby("Genre")['Genre'].count()
# Out:
# Genre
# Fiction        240
# Non Fiction    310
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Non Fiction    310
# Fiction        240
# Name: count, dtype: int64

# %%
df["Author"].value_counts()
# Out:
# Author
# Jeff Kinney                           12
# Suzanne Collins                       11
# Gary Chapman                          11
# Rick Riordan                          11
# American Psychological Association    10
#                                       ..
# Maurice Sendak                         1
# Cheryl Strayed                         1
# The Staff of The Late Show with
#        1
# Geneen Roth                            1
# Ken Follett                            1
# Name: count, Length: 248, dtype: int64

# %%
# pd.set_option('display.max_rows', None)

# %%
author_counts=df["Author"].value_counts()

# %%
author_counts[author_counts>5]
# Out:
# Author
# Jeff Kinney                           12
# Suzanne Collins                       11
# Gary Chapman                          11
# Rick Riordan                          11
# American Psychological Association    10
# Dr. Seuss                              9
# Gallup                                 9
# Rob Elliott                            8
# Bill O'Reilly                          7
# Eric Carle                             7
# Stephen R. Covey                       7
# Dav Pilkey                             7
# Stephenie Meyer                        7
# Sarah Young                            6
# Stieg Larsson                          6
# The College Board                      6
# Don Miguel Ruiz                        6
# Harper Lee                             6
# J.K. Rowling                           6
# E L James                              6
# Name: count, dtype: int64

# %%
df['Year'].min()
# Out:
# 2009

# %%
df['Year'].max()
# Out:
# 2019

# %%
df.groupby('Year')["Price"].mean()
# Out:
# Year
# 2009    15.40
# 2010    13.48
# 2011    15.10
# 2012    15.30
# 2013    14.60
# 2014    14.64
# 2015    10.42
# 2016    13.18
# 2017    11.38
# 2018    10.52
# 2019    10.08
# Name: Price, dtype: float64

# %%
df[df['Year']==2015]['Genre'].value_counts()
# Out:
# Genre
# Non Fiction    33
# Fiction        17
# Name: count, dtype: int64

# %%
df[df['Year']==2014]['Genre'].value_counts()
# Out:
# Genre
# Fiction        29
# Non Fiction    21
# Name: count, dtype: int64

# %%
df.groupby('Genre')["Price"].mean()
# Out:
# Genre
# Fiction        10.850000
# Non Fiction    14.841935
# Name: Price, dtype: float64

# %%
df.groupby('Reviews')["Price"].mean()
# Out:
# Reviews
# 37        6.000000
# 220      17.000000
# 408      20.000000
# 438      15.000000
# 440      11.000000
#            ...
# 50482    11.500000
# 57271     9.666667
# 61133    11.000000
# 79446    12.500000
# 87841    15.000000
# Name: Price, Length: 346, dtype: float64

# %%
df[df['Year']==2014]['Author'].value_counts()
# Out:
# Author
# John Green                            3
# RH Disney                             2
# Rob Elliott                           2
# Veronica Roth                         2
# Laura Hillenbrand                     2
# American Psychiatric Association      1
# Jeff Kinney                           1
# Roger Priddy                          1
# Gillian Flynn                         1
# Thomas Piketty                        1
# George R. R. Martin                   1
# Anthony Doerr                         1
# Brandon Stanton                       1
# Dale Carnegie                         1
# David Perlmutter MD                   1
# Sarah Young                           1
# Bill O'Reilly                         1
# Alice Schertle                        1
# Robert Munsch                         1
# Gayle Forman                          1
# Carol S. Dweck                        1
# Dr. Seuss                             1
# Christina Baker Kline                 1
# ...

# %%
df[df['Year']==2015]['Author'].value_counts()
# Out:
# Author
# Blue Star Coloring                    2
# Johanna Basford                       2
# Marjorie Sarnat                       2
# Harper Lee                            2
# Rob Elliott                           2
# Dr. Seuss                             2
# Chris Kyle                            1
# Angie Grace                           1
# Ta-Nehisi Coates                      1
# Anthony Doerr                         1
# DK                                    1
# Coloring Books for Adults             1
# Marty Noble                           1
# Rod Campbell                          1
# Atul Gawande                          1
# Roger Priddy                          1
# Scholastic                            1
# Dale Carnegie                         1
# Giles Andreae                         1
# E L James                             1
# Sarah Young                           1
# Brandon Stanton                       1
# Robert Munsch                         1
# ...

# %%
df[df['Year']==2015]['Price'].describe()
# Out:
# count    50.000000
# mean     10.420000
# std       7.074213
# min       0.000000
# 25%       5.250000
# 50%       9.000000
# 75%      14.000000
# max      46.000000
# Name: Price, dtype: float64

# %%
df[df['Year']==2014]['Price'].describe()
# Out:
# count     50.000000
# mean      14.640000
# std       16.569901
# min        0.000000
# 25%        6.250000
# 50%       10.000000
# 75%       16.750000
# max      105.000000
# Name: Price, dtype: float64

# %%
df[df['Year']==2014].sort_values("Price",ascending=False).head(3)
# Out:
#                                                   Name  \
# 70   Diagnostic and Statistical Manual of Mental Di...
# 276  Publication Manual of the American Psychologic...
# 443                       The Official SAT Study Guide
#
#                                  Author  User Rating  Reviews  Price  Year  \
# 70     American Psychiatric Association          4.5     6679    105  2014
# 276  American Psychological Association          4.5     8580     46  2014
# 443                   The College Board          4.4     1201     40  2014
#
#            Genre
# 70   Non Fiction
# 276  Non Fiction
# 443  Non Fiction

# %%
df[df['Year']==2015].sort_values("Price",ascending=False).head(3)
# Out:
#                                                   Name  \
# 277  Publication Manual of the American Psychologic...
# 501  Thug Kitchen: The Official Cookbook: Eat Like ...
# 132                         Go Set a Watchman: A Novel
#
#                                  Author  User Rating  Reviews  Price  Year  \
# 277  American Psychological Association          4.5     8580     46  2015
# 501                        Thug Kitchen          4.6    11128     23  2015
# 132                          Harper Lee          3.6    14982     19  2015
#
#            Genre
# 277  Non Fiction
# 501  Non Fiction
# 132      Fiction

# %%
df[df['Year']==2014].shape
# Out:
# (50, 7)

# %%
df[df['Year']==2009].sort_values("Price",ascending=False).head(3)
# Out:
#                                                   Name  \
# 473                       The Twilight Saga Collection
# 346  The Book of Basketball: The NBA According to T...
# 271  Publication Manual of the American Psychologic...
#
#                                  Author  User Rating  Reviews  Price  Year  \
# 473                     Stephenie Meyer          4.7     3801     82  2009
# 346                        Bill Simmons          4.7      858     53  2009
# 271  American Psychological Association          4.5     8580     46  2009
#
#            Genre
# 473      Fiction
# 346  Non Fiction
# 271  Non Fiction

# %%
df[df['Year']==2014]["Price"].describe()
# Out:
# count     50.000000
# mean      14.640000
# std       16.569901
# min        0.000000
# 25%        6.250000
# 50%       10.000000
# 75%       16.750000
# max      105.000000
# Name: Price, dtype: float64

# %%
median=df.groupby('Year')['Price'].median()

# %%
sns.lineplot(x='Year',y='Price',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Price'>

# %%
sns.lineplot(data=median)

plt.plot()
plt.title("Median book price (2009-2019)")
# Out:
# Text(0.5, 1.0, 'Median book price (2009-2019)')

# %%
median
# Out:
# Year
# 2009    12.0
# 2010    12.5
# 2011    13.0
# 2012    13.0
# 2013    12.5
# 2014    10.0
# 2015     9.0
# 2016     9.0
# 2017     9.0
# 2018     8.0
# 2019    10.0
# Name: Price, dtype: float64
